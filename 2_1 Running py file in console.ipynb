# %% [raw]
# def add(x, y):
#     return x + y
#
#
# def test_small_numbers():
#     assert add(2, 7) == 9, "The number sums is incorrect"
#
#
# def test_big_numbers():
#     assert add(125, 371) == 96, "The number sums is incorrect"

# %% [markdown]
# Previous script is stored under `02_PyTest_start.py`. Since the code contains assertion and warning message, we can run a test from the script to verify the function, wether it's correct or not.

# %% [markdown]
# ## Running The Terminal

# %% [markdown]
# ### 1. Press `Windows + R` then type cmd to open windows prompt into the default folder
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. Go to Selenium Virtual Environment directory and activate the script
#
# - Go to Selenium Virtual Environment directory <br>
# ![image.png](attachment:image.png)
#
# - activate the script <br>
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ### 2. Go to the Project Folder & run the test
# - Navigate to project folder directory (`D:\Docs\Python\VS Code\Selenium\Selenium-WebDriver-Python\test\02_PyTest_Start.py`) <br>
# ![image.png](attachment:image-2.png)
#
# - Validate the directory content by typing `dir` <br>
# ![image.png](attachment:image.png)
#
# - Run the test by type `"pytest"` on the current working directory or adding the filenames to run the test on the specific file only <br>
# ![image.png](attachment:image-5.png)
#
# - Check the console logs for the results
# ![image.png](attachment:image-4.png)
